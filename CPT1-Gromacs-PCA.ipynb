# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# %%
df = pd.read_excel('Gromacs-PCA-table.xlsx')

# %%
#Apo CPT1

apo = df.loc[0:100,['PC1','PC2']]


apo_plot = sns.jointplot(x='PC1',y='PC2',data=apo, color = 'silver', kind='kde')
apo_plot.ax_marg_x.set_xlim(-12, 12)
apo_plot.ax_marg_y.set_ylim(-12, 12)
   
   


fig1 = plt.gcf()
plt.draw()
fig1.savefig('Apo_CPT1-PCA.pdf', dpi=600)

# %%
#Alpha

Alpha = df.loc[101:201,['PC1','PC2']]


Alpha_plot = sns.jointplot(x='PC1',y='PC2',data=Alpha, color = '#f2b77c', kind='kde')


Alpha_plot.ax_marg_x.set_xlim(-12, 12)
Alpha_plot.ax_marg_y.set_ylim(-12, 12)


fig2 = plt.gcf()
plt.draw()
fig2.savefig('Alpha_CPT1-PCA.pdf', dpi=600)

# %%
#Gamma

Gamma = df.loc[202:302,['PC1','PC2']]


Gamma_plot = sns.jointplot(x='PC1',y='PC2',data=Gamma, color = '#197c8dff', kind='kde')
Gamma_plot.ax_marg_x.set_xlim(-12, 12)
Gamma_plot.ax_marg_y.set_ylim(-12, 12)





fig3 = plt.gcf()
plt.draw()
fig3.savefig('Gamma_CPT1-PCA.pdf', dpi=600)

# %%
#Arachidonic

Arachidonic = df.loc[303:403,['PC1','PC2']]


Arachidonic_plot = sns.jointplot(x='PC1',y='PC2',data=Arachidonic, color = '#f71480ff', kind='kde')
Arachidonic_plot.ax_marg_x.set_xlim(-12, 12)
Arachidonic_plot.ax_marg_y.set_ylim(-12, 12)





fig4 = plt.gcf()
plt.draw()
fig4.savefig('Arachdonic_CPT1-PCA.pdf', dpi=600)

# %%
#Apo CPT1

apo_2 = df.loc[0:100,['PC1','PC3']]


apo_plot_2 = sns.jointplot(x='PC1',y='PC3',data=apo_2, color = 'silver', kind='kde')
apo_plot_2.ax_marg_x.set_xlim(-12, 12)
apo_plot_2.ax_marg_y.set_ylim(-12, 12)




fig5 = plt.gcf()
plt.draw()
fig5.savefig('Apo_CPT1-PCA-2.pdf', dpi=600)

# %%
#Alpha

Alpha_2 = df.loc[101:201,['PC1','PC3']]


Alpha_plot_2 = sns.jointplot(x='PC1',y='PC3',data=Alpha_2, color = '#f2b77c', kind='kde')


Alpha_plot_2.ax_marg_x.set_xlim(-12, 12)
Alpha_plot_2.ax_marg_y.set_ylim(-12, 12)


fig6 = plt.gcf()
plt.draw()

fig6.savefig('Alpha_CPT1-PCA-2.pdf', dpi=600)

# %%
#Gamma

Gamma_2 = df.loc[202:302,['PC1','PC3']]


Gamma_plot_2 = sns.jointplot(x='PC1',y='PC3',data=Gamma_2, color = '#197c8dff', kind='kde')
Gamma_plot_2.ax_marg_x.set_xlim(-12, 12)
Gamma_plot_2.ax_marg_y.set_ylim(-12, 12)





fig7 = plt.gcf()
plt.draw()
fig7.savefig('Gamma_CPT1-PCA-2.pdf', dpi=600)

# %%
#Arachidonic

Arachidonic_2 = df.loc[303:403,['PC1','PC3']]


Arachidonic_plot_2 = sns.jointplot(x='PC1',y='PC3',data=Arachidonic_2, color = '#f71480ff', kind='kde')
Arachidonic_plot_2.ax_marg_x.set_xlim(-12, 12)
Arachidonic_plot_2.ax_marg_y.set_ylim(-12, 12)




fig8 = plt.gcf()
plt.draw()
fig8.savefig('Arachdonic_CPT1-PCA-2.pdf', dpi=600)

# %%
#Apo CPT1

apo_3 = df.loc[0:100,['PC2','PC3']]


apo_plot_3 = sns.jointplot(x='PC2',y='PC3',data=apo_3, color = 'silver', kind='kde')
apo_plot_3.ax_marg_x.set_xlim(-12, 12)
apo_plot_3.ax_marg_y.set_ylim(-12, 12)




fig9 = plt.gcf()
plt.draw()
fig9.savefig('Apo_CPT1-PCA-3.pdf', dpi=600)

# %%
## Alpha

Alpha_3 = df.loc[101:201,['PC2','PC3']]


Alpha_plot_3 = sns.jointplot(x='PC2',y='PC3',data=Alpha_3, color = '#f2b77c', kind='kde')


Alpha_plot_3.ax_marg_x.set_xlim(-12, 12)
Alpha_plot_3.ax_marg_y.set_ylim(-12, 12)


fig10 = plt.gcf()
plt.draw()
fig10.savefig('Alpha_CPT1-PCA-3.pdf', dpi=600)

# %%
#Gamma

Gamma_3 = df.loc[202:302,['PC2','PC3']]


Gamma_plot_3 = sns.jointplot(x='PC2',y='PC3',data=Gamma_3, color = '#197c8dff', kind='kde')
Gamma_plot_3.ax_marg_x.set_xlim(-12, 12)
Gamma_plot_3.ax_marg_y.set_ylim(-12, 12)





fig11 = plt.gcf()
plt.draw()
fig11.savefig('Gamma_CPT1-PCA-3.pdf', dpi=600)

# %%
#Arachidonic

Arachidonic_3 = df.loc[303:403,['PC2','PC3']]


Arachidonic_plot_3 = sns.jointplot(x='PC2',y='PC3',data=Arachidonic_3, color = '#f71480ff', kind='kde')
Arachidonic_plot_3.ax_marg_x.set_xlim(-12, 12)
Arachidonic_plot_3.ax_marg_y.set_ylim(-12, 12)





fig12 = plt.gcf()
plt.draw()
fig12.savefig('Arachdonic_CPT1-PCA-3.pdf', dpi=600)
